# %% [markdown]
# Peço perdão por não mandar o Colab da forma como foi mencionada no vídeo, mas estou com um problema (desde a fase passada) onde o Colab não acha o meu repositório do GitHub, mas segue o link:https://colab.research.google.com/drive/17Hr5VUt_QfyA_7Q2z_-0FCRyp8akHVv4#scrollTo=5gfQTRPGYQxf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# conecta Drive.

# %%
# %%writefile /content/data.yaml
#
# train: /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/train
# val: /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/val
# test: /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/test
#
# nc: 2
# names: ['banana', 'apple']
# Out:
# Writing /content/data.yaml

# %% [markdown]
# cria o arquivo de configuração.

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17898, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 17898 (delta 61), reused 40 (delta 40), pack-reused 17818 (from 2)
# Receiving objects: 100% (17898/17898), 17.03 MiB | 15.94 MiB/s, done.
# Resolving deltas: 100% (12192/12192), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 85.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %% [markdown]
# instala YOLO

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data /content/data.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: ERROR Error while calling W&B API: api key too short (<Response [401]>)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# Após 30 épocas de treinamento, o modelo YOLOv5 apresentou ótimo desempenho na detecção dos objetos banana e maçã. O mAP@50 atingiu 93,3%, demonstrando alta capacidade de identificação e localização dos objetos nas imagens. O recall de 87,5% indica que a maioria dos objetos presentes foi detectada corretamente.

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data /content/data.yaml --weights yolov5s.pt --name exp60
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: ERROR Error while calling W&B API: api key too short (<Response [401]>)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# Treino

# %% [markdown]
# Ao comparar os treinamentos com 30 e 60 épocas, observou-se que o modelo com 30 épocas apresentou melhor mAP@50 (93,3%), indicando ótima detecção geral. Já o modelo com 60 épocas apresentou maior precisão e melhor mAP@50:95 (65,1%), demonstrando caixas delimitadoras mais refinadas e melhor desempenho em critérios mais rígidos.
#
# Conclui-se que 30 épocas foram suficientes para excelente resultado geral, enquanto 60 épocas trouxeram refinamento adicional ao custo de maior tempo de treinamento.

# %%
# !python detect.py --weights runs/train/exp60/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/test
# Out:
# detect: weights=['runs/train/exp60/weights/best.pt'], source=/content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-478-g6c66ecd5 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/test/Image_11.jpg: 448x640 1 banana, 44.0ms
# image 2/8 /content/drive/MyDrive/FIAP/Atividade_Fase6/dataset/images/test/Image_12.jpg: 448x640 (no detections), 8.7ms
# ...

# %%
# !ls runs/detect/exp
# Out:
#  Image_11.jpg   Image_13.jpg   Image_20.jpg	   Image_5.webp
#  Image_12.jpg   Image_17.jpg  'Image_25 (1).jpg'  'Image_7 (1).png'

# %%
# !cp -r runs/detect/exp "/content/drive/MyDrive/FIAP/Atividade_Fase6/resultados_teste"
